# %% [markdown]
# #2. Load the dataset.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import numpy as np
import pandas as pd

data = pd.read_csv('/content/abalone.csv')
data.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %% [markdown]
# #3. Perform Below Visualizations.

# %%
# Univariate Analysis

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

data=pd.read_csv('/content/abalone.csv')
data.hist(column='Diameter', grid=False, edgecolor='black')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fca9ed26fd0>]],
#       dtype=object)

# %%
# Bi - Variate Analysis

import pandas as pd
data = pd.read_csv('/content/abalone.csv', index_col=0)
data.head()
data[data['Length'] > 100].plot.scatter(x='Length', y='Height')
data.head()
# Out:
#      Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# Sex
# M     0.455     0.365   0.095        0.5140          0.2245          0.1010
# M     0.350     0.265   0.090        0.2255          0.0995          0.0485
# F     0.530     0.420   0.135        0.6770          0.2565          0.1415
# M     0.440     0.365   0.125        0.5160          0.2155          0.1140
# I     0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#      Shell weight  Rings
# Sex
# M           0.150     15
# M           0.070      7
# F           0.210      9
# M           0.155     10
# I           0.055      7

# %%
# Multi - Variate Analysis

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
data=pd.read_csv('/content/abalone.csv')
data.head()
data.plot.line()
pd.plotting.scatter_matrix(data.loc[:, 'Length':'Whole weight'], diagonal='kde',figsize=(20,15))
plt.show()

# %% [markdown]
# # 4. Perform descriptive statistics on the dataset.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
data=pd.read_csv('/content/abalone.csv')
data.head()
data.plot.line()
pd.plotting.scatter_matrix(data.loc[:, 'Height':'Whole weight'], diagonal='kde',figsize=(20,15))
plt.show()
print(data.sum())
# Out:
# Sex               MMFMIIFFMFFMMFFMIFMMMIFFFFFMMMMFMFFMFFFMFFIIII...
# Length                                                     2188.715
# Diameter                                                    1703.72
# Height                                                       582.76
# Whole weight                                               3461.656
# Shucked weight                                             1501.078
# Viscera weight                                             754.3395
# Shell weight                                               997.5965
# Rings                                                         41493
# dtype: object

# %% [markdown]
# #5.Handle the Missing values.

# %%
import pandas as pd

dataset = pd.read_csv('/content/abalone.csv')

print('Data with missing values')
print(dataset)

print('\nData without missing values')
dataset.dropna(inplace = True)
print(dataset)
# Out:
# Data with missing values
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# ...

# %% [markdown]
# # 6. Find the outliers and replace the outliers

# %%
import pandas as pd
import numpy as np
data = pd.read_csv('/content/abalone.csv')

print(data.shape)
data.describe()
# Out:
# (4177, 9)
#             Length     Diameter       Height  Whole weight  Shucked weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera weight  Shell weight        Rings
# count     4177.000000   4177.000000  4177.000000
# mean         0.180594      0.238831     9.933684
# std          0.109614      0.139203     3.224169
# min          0.000500      0.001500     1.000000
# ...

# %% [markdown]
# # 7. Check for Categorical columns and perform encoding.

# %%
import pandas as pd
import numpy as np
data = pd.read_csv('/content/abalone.csv')
pd.get_dummies(data, columns=["Shucked weight"])
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Viscera weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.1010
# 1      M   0.350     0.265   0.090        0.2255          0.0485
# 2      F   0.530     0.420   0.135        0.6770          0.1415
# 3      M   0.440     0.365   0.125        0.5160          0.1140
# 4      I   0.330     0.255   0.080        0.2050          0.0395
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.2390
# 4173   M   0.590     0.440   0.135        0.9660          0.2145
# 4174   M   0.600     0.475   0.205        1.1760          0.2875
# 4175   F   0.625     0.485   0.150        1.0945          0.2610
# 4176   M   0.710     0.555   0.195        1.9485          0.3765
#
#       Shell weight  Rings  Shucked weight_0.001  Shucked weight_0.0025  ...  \
# 0           0.1500     15                     0                      0  ...
# ...

# %% [markdown]
# #8. Split the data into dependent and independent variables.

# %%
x = data.iloc[:,0:4].values
y = data.iloc[:,4:5].values
print(x,y)
# Out:
# [['M' 0.455 0.365 0.095]
#  ['M' 0.35 0.265 0.09]
#  ['F' 0.53 0.42 0.135]
#  ...
#  ['M' 0.6 0.475 0.205]
#  ['F' 0.625 0.485 0.15]
#  ['M' 0.71 0.555 0.195]] [[0.514 ]
#  [0.2255]
#  [0.677 ]
#  ...
#  [1.176 ]
#  [1.0945]
#  [1.9485]]

# %% [markdown]
# #9. Scale the independent variables

# %%
import pandas as pd
import numpy as np
data = pd.read_csv('/content/abalone.csv')

X= data.iloc[ : , :-1].values

y= data.iloc[ : , 4].values

print(X,y)
# Out:
# [['M' 0.455 0.365 ... 0.2245 0.101 0.15]
#  ['M' 0.35 0.265 ... 0.0995 0.0485 0.07]
#  ['F' 0.53 0.42 ... 0.2565 0.1415 0.21]
#  ...
#  ['M' 0.6 0.475 ... 0.5255 0.2875 0.308]
#  ['F' 0.625 0.485 ... 0.531 0.261 0.296]
#  ['M' 0.71 0.555 ... 0.9455 0.3765 0.495]] [0.514  0.2255 0.677  ... 1.176  1.0945 1.9485]

# %% [markdown]
# # 10. Split the data into training and testing

# %%
from sklearn.model_selection import train_test_split

xtrain,xtest,ytrain,ytest =train_test_split(x,y,test_size=4,random_state=0)

xtrain.shape, xtest.shape
# Out:
# ((4173, 4), (4, 4))

# %% [markdown]
# #11.Build the Model

# %%
from sklearn import linear_model
X = data["Length"].to_numpy().reshape(-1, 1)
y = data["Height"].to_numpy().reshape(-1, 1)
lm = linear_model.LinearRegression()
model = lm.fit(X,y)
print(model.coef_)
print(model.intercept_)
# Out:
# [[0.28822793]]
# [-0.01151276]

# %% [markdown]
# #12.Train the Model

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
model = lm.fit(X,y)
print(model.coef_)
print(model.intercept_)
model.fit(X, y)
print(model.coef_)
print(model.intercept_)
predictions = model.predict(X)
plt.scatter(y, predictions)
# Out:
# [[0.28822793]]
# [-0.01151276]
# [[0.28822793]]
# [-0.01151276]

# %% [markdown]
# #test the model
